# %%
import numpy as np
import pandas as pd

# %%
customers = pd.read_csv("customers.csv")

# %%
customers = pd.read_csv("customers.csv")

# %%
customers = pd.read_csv("customers.csv")
products = pd.read_csv("products.csv")
sellers = pd.read_csv("sellers.csv")
orders = pd.read_csv("orders.csv")
order_items = pd.read_csv("order_items.csv")

# %%
customers.shape
products.shape
sellers.shape
orders.shape
order_items.shape
# Out:
# (105953, 9)

# %%
customers = pd.read_csv("customers.csv")

# %%
customers.shape
# Out:
# (2000, 9)

# %%
products = pd.read_csv("products.csv")

# %%
products.shape
# Out:
# (420, 7)

# %%
order_items = pd.read_csv("order_items.csv")

# %%
order_items.shape
# Out:
# (105953, 9)

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       2000 non-null   str
#  1   Customer_Name     2000 non-null   str
#  2   Gender            2000 non-null   str
#  3   Age               2000 non-null   int64
#  4   Customer_Segment  2000 non-null   str
#  5   City              2000 non-null   str
#  6   State             2000 non-null   str
#  7   Region            2000 non-null   str
#  8   Signup_Date       2000 non-null   str
# dtypes: int64(1), str(8)
# memory usage: 140.8 KB

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    420 non-null    str
#  1   Product_Name  420 non-null    str
#  2   Category      420 non-null    str
#  3   Subcategory   420 non-null    str
#  4   Brand         420 non-null    str
#  5   Unit_Cost     420 non-null    float64
#  6   Unit_Price    420 non-null    int64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 23.1 KB

# %%
sellers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Seller_ID      100 non-null    str
#  1   Seller_Name    100 non-null    str
#  2   Seller_Type    100 non-null    str
#  3   Seller_Region  100 non-null    str
# dtypes: str(4)
# memory usage: 3.3 KB

# %%
customers.isnull().sum()
# Out:
# Customer_ID         0
# Customer_Name       0
# Gender              0
# Age                 0
# Customer_Segment    0
# City                0
# State               0
# Region              0
# Signup_Date         0
# dtype: int64

# %%
sellers.isnull().sum()
# Out:
# Seller_ID        0
# Seller_Name      0
# Seller_Type      0
# Seller_Region    0
# dtype: int64

# %%
products.isnull().sum()
# Out:
# Product_ID      0
# Product_Name    0
# Category        0
# Subcategory     0
# Brand           0
# Unit_Cost       0
# Unit_Price      0
# dtype: int64

# %%
order_items.isnull().sum()
# Out:
# Order_ID        0
# Product_ID      0
# Seller_ID       0
# Quantity        0
# Discount        0
# Sales           0
# Cost            0
# Profit          0
# Order_Status    0
# dtype: int64

# %%
orders.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Seller_ID         0
# Order_Status      0
# Payment_Method    0
# Shipping_Mode     0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_itmes.duplicates().sum()
sellers.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 order_itmes.duplicates().sum()
#       2 sellers.duplicated().sum()
#
# NameError: name 'order_itmes' is not defined

# %%
order_items.duplicates().sum()
sellers.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 order_items.duplicates().sum()
#       2 sellers.duplicated().sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
order_items.duplicated().sum()
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.describe()
# Out:
#               Age
# count  2000.00000
# mean     43.48100
# std      14.76952
# min      18.00000
# 25%      31.00000
# 50%      44.00000
# 75%      56.00000
# max      68.00000

# %%
sellers.describe()
# Out:
#        Seller_ID Seller_Name Seller_Type Seller_Region
# count        100         100         100           100
# unique       100         100           3             4
# top        S0001  Seller 001     Premium          East
# freq           1           1          41            29

# %%
orders.describe()
# Out:
#         Order_ID  Order_Date Customer_ID Seller_ID Order_Status  \
# count      50000       50000       50000     50000        50000
# unique     50000         956        2000       100            4
# top     O0000001  2026-05-16      C01007     S0048    Completed
# freq           1          77          44       553        42954
#
#        Payment_Method Shipping_Mode
# count           50000         50000
# unique              6             3
# top            Wallet      Same Day
# freq             8542         16830

# %%
products.describe()
# Out:
#           Unit_Cost    Unit_Price
# count    420.000000    420.000000
# mean    5541.953500   8940.952381
# std     9195.021243  14677.124540
# min        0.000000      0.000000
# 25%      724.042500   1200.000000
# 50%     2124.530000   3400.000000
# 75%     4927.100000   8075.000000
# max    64646.390000  89800.000000

# %%
order_items.describe()
# Out:
#             Quantity       Discount          Sales           Cost  \
# count  105953.000000  105953.000000  105953.000000  105953.000000
# mean        2.498400       0.110989   19888.957122   13895.131151
# std         1.117983       0.077258   36917.744589   25992.169875
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.050000    2375.000000    1642.580000
# 50%         3.000000       0.100000    6402.000000    4528.050000
# 75%         3.000000       0.150000   18624.000000   12986.760000
# max         4.000000       0.300000  359200.000000  258585.560000
#
#               Profit
# count  105953.000000
# mean     5993.825971
# std     12486.239649
# min    -23105.560000
# 25%       599.010000
# 50%      1736.490000
# 75%      5444.760000
# max    175884.360000

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers.shape
sellers.info()
sellers.duplicated().sum()
sellers.isnull().sum()
sellers.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Seller_ID      100 non-null    str
#  1   Seller_Name    100 non-null    str
#  2   Seller_Type    100 non-null    str
#  3   Seller_Region  100 non-null    str
# dtypes: str(4)
# memory usage: 3.3 KB
#        Seller_ID Seller_Name Seller_Type Seller_Region
# count        100         100         100           100
# unique       100         100           3             4
# top        S0001  Seller 001     Premium          East
# freq           1           1          41            29

# %%
sellers.shape
# Out:
# (100, 4)

# %%
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers.isnull().sum()
# Out:
# Seller_ID        0
# Seller_Name      0
# Seller_Type      0
# Seller_Region    0
# dtype: int64

# %%
sellers.shape,
sellers.info(),
sellers.duplicated().sum(),
sellers.isnull().sum(),
sellers.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Seller_ID      100 non-null    str
#  1   Seller_Name    100 non-null    str
#  2   Seller_Type    100 non-null    str
#  3   Seller_Region  100 non-null    str
# dtypes: str(4)
# memory usage: 3.3 KB
#        Seller_ID Seller_Name Seller_Type Seller_Region
# count        100         100         100           100
# unique       100         100           3             4
# top        S0001  Seller 001     Premium          East
# freq           1           1          41            29

# %%
sellers.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sellers.shape()
#
# TypeError: 'tuple' object is not callable

# %%
orders.shape
# Out:
# (50000, 7)

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Seller_ID         0
# Order_Status      0
# Payment_Method    0
# Shipping_Mode     0
# dtype: int64

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        50000 non-null  str
#  1   Order_Date      50000 non-null  str
#  2   Customer_ID     50000 non-null  str
#  3   Seller_ID       50000 non-null  str
#  4   Order_Status    50000 non-null  str
#  5   Payment_Method  50000 non-null  str
#  6   Shipping_Mode   50000 non-null  str
# dtypes: str(7)
# memory usage: 2.7 MB

# %%
orders.describe()
# Out:
#         Order_ID  Order_Date Customer_ID Seller_ID Order_Status  \
# count      50000       50000       50000     50000        50000
# unique     50000         956        2000       100            4
# top     O0000001  2026-05-16      C01007     S0048    Completed
# freq           1          77          44       553        42954
#
#        Payment_Method Shipping_Mode
# count           50000         50000
# unique              6             3
# top            Wallet      Same Day
# freq             8542         16830

# %%
order_items.shape
order_items.info()
order_items.duplicated().sum()
order_items.isnull().sum()
order_items.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105953 entries, 0 to 105952
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Order_ID      105953 non-null  str
#  1   Product_ID    105953 non-null  str
#  2   Seller_ID     105953 non-null  str
#  3   Quantity      105953 non-null  int64
#  4   Discount      105953 non-null  float64
#  5   Sales         105953 non-null  float64
#  6   Cost          105953 non-null  float64
#  7   Profit        105953 non-null  float64
#  8   Order_Status  105953 non-null  str
# dtypes: float64(4), int64(1), str(4)
# memory usage: 7.3 MB
#             Quantity       Discount          Sales           Cost  \
# count  105953.000000  105953.000000  105953.000000  105953.000000
# mean        2.498400       0.110989   19888.957122   13895.131151
# std         1.117983       0.077258   36917.744589   25992.169875
# min         1.000000       0.000000       0.000000       0.000000
# ...

# %%
order_items.shape
# Out:
# (105953, 9)

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_items.isnull().sum()
# Out:
# Order_ID        0
# Product_ID      0
# Seller_ID       0
# Quantity        0
# Discount        0
# Sales           0
# Cost            0
# Profit          0
# Order_Status    0
# dtype: int64

# %%
products.describe()
order_items.describe()
# Out:
#             Quantity       Discount          Sales           Cost  \
# count  105953.000000  105953.000000  105953.000000  105953.000000
# mean        2.498400       0.110989   19888.957122   13895.131151
# std         1.117983       0.077258   36917.744589   25992.169875
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.050000    2375.000000    1642.580000
# 50%         3.000000       0.100000    6402.000000    4528.050000
# 75%         3.000000       0.150000   18624.000000   12986.760000
# max         4.000000       0.300000  359200.000000  258585.560000
#
#               Profit
# count  105953.000000
# mean     5993.825971
# std     12486.239649
# min    -23105.560000
# 25%       599.010000
# 50%      1736.490000
# 75%      5444.760000
# max    175884.360000

# %%
products.describe()
# Out:
#           Unit_Cost    Unit_Price
# count    420.000000    420.000000
# mean    5541.953500   8940.952381
# std     9195.021243  14677.124540
# min        0.000000      0.000000
# 25%      724.042500   1200.000000
# 50%     2124.530000   3400.000000
# 75%     4927.100000   8075.000000
# max    64646.390000  89800.000000

# %%
order_items.describe()
# Out:
#             Quantity       Discount          Sales           Cost  \
# count  105953.000000  105953.000000  105953.000000  105953.000000
# mean        2.498400       0.110989   19888.957122   13895.131151
# std         1.117983       0.077258   36917.744589   25992.169875
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.050000    2375.000000    1642.580000
# 50%         3.000000       0.100000    6402.000000    4528.050000
# 75%         3.000000       0.150000   18624.000000   12986.760000
# max         4.000000       0.300000  359200.000000  258585.560000
#
#               Profit
# count  105953.000000
# mean     5993.825971
# std     12486.239649
# min    -23105.560000
# 25%       599.010000
# 50%      1736.490000
# 75%      5444.760000
# max    175884.360000

# %%
products[products["Unit_Cost"]==0]
# Out:
#     Product_ID          Product_Name         Category Subcategory      Brand  \
# 345      P0346  PrimeLine Writing 01  Office Supplies     Writing  PrimeLine
#
#      Unit_Cost  Unit_Price
# 345        0.0           0

# %%
products[products["Unit_Price"]==0]
# Out:
#     Product_ID          Product_Name         Category Subcategory      Brand  \
# 345      P0346  PrimeLine Writing 01  Office Supplies     Writing  PrimeLine
#
#      Unit_Cost  Unit_Price
# 345        0.0           0

# %%
products[products["Unit_Cost"]>products["Unit_Price"]]
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_Name, Category, Subcategory, Brand, Unit_Cost, Unit_Price]
# Index: []

# %%
order_items[order_items["Sales"]==0]
# Out:
#         Order_ID Product_ID Seller_ID  Quantity  Discount  Sales  Cost  \
# 890     O0000415      P0346     S0063         1      0.08    0.0   0.0
# 1181    O0000547      P0346     S0027         2      0.00    0.0   0.0
# 1362    O0000627      P0346     S0085         2      0.05    0.0   0.0
# 1501    O0000696      P0346     S0096         2      0.15    0.0   0.0
# 1857    O0000857      P0346     S0074         4      0.25    0.0   0.0
# ...          ...        ...       ...       ...       ...    ...   ...
# 104259  O0049211      P0346     S0044         1      0.12    0.0   0.0
# 104472  O0049316      P0346     S0051         3      0.00    0.0   0.0
# 104500  O0049328      P0346     S0029         4      0.05    0.0   0.0
# 104504  O0049330      P0346     S0080         1      0.10    0.0   0.0
# 105364  O0049734      P0346     S0005         4      0.12    0.0   0.0
#
#         Profit Order_Status
# 890        0.0    Completed
# 1181       0.0    Completed
# ...

# %%
order_items[order_items["Cost"]==0]
# Out:
#         Order_ID Product_ID Seller_ID  Quantity  Discount  Sales  Cost  \
# 890     O0000415      P0346     S0063         1      0.08    0.0   0.0
# 1181    O0000547      P0346     S0027         2      0.00    0.0   0.0
# 1362    O0000627      P0346     S0085         2      0.05    0.0   0.0
# 1501    O0000696      P0346     S0096         2      0.15    0.0   0.0
# 1857    O0000857      P0346     S0074         4      0.25    0.0   0.0
# ...          ...        ...       ...       ...       ...    ...   ...
# 104259  O0049211      P0346     S0044         1      0.12    0.0   0.0
# 104472  O0049316      P0346     S0051         3      0.00    0.0   0.0
# 104500  O0049328      P0346     S0029         4      0.05    0.0   0.0
# 104504  O0049330      P0346     S0080         1      0.10    0.0   0.0
# 105364  O0049734      P0346     S0005         4      0.12    0.0   0.0
#
#         Profit Order_Status
# 890        0.0    Completed
# 1181       0.0    Completed
# ...

# %%
order_items[order_items["Profit"]<0]
# Out:
#         Order_ID Product_ID Seller_ID  Quantity  Discount     Sales  \
# 244     O0000114      P0120     S0066         4      0.25   23400.0
# 467     O0000218      P0309     S0093         1      0.25     825.0
# 559     O0000260      P0312     S0080         2      0.25    1800.0
# 710     O0000329      P0153     S0075         2      0.25    8850.0
# 834     O0000384      P0004     S0093         4      0.25  187800.0
# ...          ...        ...       ...       ...       ...       ...
# 105284  O0049696      P0153     S0095         1      0.25    4425.0
# 105461  O0049777      P0223     S0013         4      0.25     900.0
# 105701  O0049883      P0124     S0030         1      0.25    2475.0
# 105750  O0049906      P0040     S0056         2      0.25   12600.0
# 105945  O0049997      P0004     S0043         2      0.30   87640.0
#
#              Cost   Profit Order_Status
# 244      24080.16  -680.16    Completed
# 467        837.35   -12.35    Completed
# ...

# %%
order_items[order_items["Sales"] == 0]["Order_Status"].value_counts()
# Out:
# Order_Status
# Completed    214
# Returned      14
# Cancelled     12
# Pending        6
# Name: count, dtype: int64

# %%
products_clean = products.copy()

# %%
products_clean = orders.copy()

# %%
order_items_clean = order_items.copy()

# %%
orders_clean = orders.copy()

# %%
customers_clean = customers.copy()

# %%
sellers_clean = sellers.copy()

# %%
products_clean.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Seller_ID', 'Order_Status',
#        'Payment_Method', 'Shipping_Mode'],
#       dtype='str')

# %%
products_clean.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_ID',
#  'Seller_ID',
#  'Order_Status',
#  'Payment_Method',
#  'Shipping_Mode']

# %%
products_clean = products.copy()

# %%
products_clean.columns.tolist()
# Out:
# ['Product_ID',
#  'Product_Name',
#  'Category',
#  'Subcategory',
#  'Brand',
#  'Unit_Cost',
#  'Unit_Price']

# %%
products_clean[products_clean["Product_ID"] == "P0346"]
# Out:
#     Product_ID          Product_Name         Category Subcategory      Brand  \
# 345      P0346  PrimeLine Writing 01  Office Supplies     Writing  PrimeLine
#
#      Unit_Cost  Unit_Price
# 345        0.0           0

# %%
products_clean.loc[
    products_clean["Product_ID"] == "P0346",
    ["Unit_Cost", "Unit_Price"]
] = [300, 500]

# %%
products_clean[products_clean["Product_ID"] == "P0346"]
# Out:
#     Product_ID          Product_Name         Category Subcategory      Brand  \
# 345      P0346  PrimeLine Writing 01  Office Supplies     Writing  PrimeLine
#
#      Unit_Cost  Unit_Price
# 345      300.0         500

# %%
print("customers_clean:", customers_clean.columns.tolist())
# Out:
# customers_clean: ['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'Customer_Segment', 'City', 'State', 'Region', 'Signup_Date']

# %%
print("customers_clean:", customers_clean.columns.tolist())
print("products_clean:", products_clean.columns.tolist())
print("sellers_clean:", sellers_clean.columns.tolist())
print("orders_clean:", orders_clean.columns.tolist())
print("order_items_clean:", order_items_clean.columns.tolist())
# Out:
# customers_clean: ['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'Customer_Segment', 'City', 'State', 'Region', 'Signup_Date']
# products_clean: ['Product_ID', 'Product_Name', 'Category', 'Subcategory', 'Brand', 'Unit_Cost', 'Unit_Price']
# sellers_clean: ['Seller_ID', 'Seller_Name', 'Seller_Type', 'Seller_Region']
# orders_clean: ['Order_ID', 'Order_Date', 'Customer_ID', 'Seller_ID', 'Order_Status', 'Payment_Method', 'Shipping_Mode']
# order_items_clean: ['Order_ID', 'Product_ID', 'Seller_ID', 'Quantity', 'Discount', 'Sales', 'Cost', 'Profit', 'Order_Status']

# %%
p0346_mask = order_items_clean["Product_ID"]=="P0346"

order_items_clean.loc[p0346_mask, "Sales"]=(
    500
    * order_items_clean.loc[p0346_mask, "Quantity"]
    * (1-order_items_clean.loc[p0346_mask, "Discount"])
)

order_items_clean.loc[p0346_mask, "Cost"]=(
    300
    * order_items_clean.loc[p0346_mask, "Quantity"]
)

order_items_clean.loc[p0346_mask, "Profit"]=(
    order_items_clean.loc[p0346_mask, "Sales"]
    - order_items_clean.loc[p0346_mask, "Cost"]
)

# %%
order_items_clean[order_items_clean["Product_ID"]=="P0346"].head()
# Out:
#       Order_ID Product_ID Seller_ID  Quantity  Discount   Sales    Cost  \
# 890   O0000415      P0346     S0063         1      0.08   460.0   300.0
# 1181  O0000547      P0346     S0027         2      0.00  1000.0   600.0
# 1362  O0000627      P0346     S0085         2      0.05   950.0   600.0
# 1501  O0000696      P0346     S0096         2      0.15   850.0   600.0
# 1857  O0000857      P0346     S0074         4      0.25  1500.0  1200.0
#
#       Profit Order_Status
# 890    160.0    Completed
# 1181   400.0    Completed
# 1362   350.0    Completed
# 1501   250.0    Completed
# 1857   300.0    Completed

# %%
order_items_clean[
    order_items_clean["Product_ID"]=="P0346"][["Quantity", "Discount", "Sales", "Cost", "Profit"]].describe()
# Out:
#          Quantity    Discount        Sales         Cost      Profit
# count  246.000000  246.000000   246.000000   246.000000  246.000000
# mean     2.455285    0.105650  1101.341463   736.585366  364.756098
# std      1.093596    0.075751   506.893731   328.078709  196.266014
# min      1.000000    0.000000   375.000000   300.000000   75.000000
# 25%      1.250000    0.030000   562.500000   375.000000  185.000000
# 50%      2.000000    0.100000  1000.000000   600.000000  320.000000
# 75%      3.000000    0.150000  1500.000000   900.000000  555.000000
# max      4.000000    0.250000  2000.000000  1200.000000  800.000000

# %%
products_clean[products_clean["Unit_Price"]==0]
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_Name, Category, Subcategory, Brand, Unit_Cost, Unit_Price]
# Index: []

# %%
products_clean[products_clean["Unit_Cost"]==0]
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_Name, Category, Subcategory, Brand, Unit_Cost, Unit_Price]
# Index: []

# %%
order_items_clean[order_items_clean["Sales"]==0]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Product_ID, Seller_ID, Quantity, Discount, Sales, Cost, Profit, Order_Status]
# Index: []

# %%
print(customers_clean["Signup_Date"].dtype)
# Out:
# str

# %%
print(orders_clean["Order_Date"].dtype)
# Out:
# str

# %%
customers_clean["Signup_Date"]=pd.to_datetime(customers_clean["Signup_Date"])

# %%
print(customers_clean["Signup_Date"].dtype)
# Out:
# datetime64[us]

# %%
orders_clean["Order_Date"]=pd.to_datetime(orders_clean["Order_Date"])

# %%
print(orders_clean["Order_Date"].dtype)
# Out:
# datetime64[us]

# %%
print(customers_clean["Signup_Date"].isnull().sum())
print(orders_clean["Order_Date"].isnull().sum())
# Out:
# 0
# 0

# %%
orders_clean["Customer_ID"].isin(customers_clean["Customer_ID"]).value_counts()
# Out:
# Customer_ID
# True    50000
# Name: count, dtype: int64

# %%
orders_clean["Seller_ID"].isin(
    sellers_clean["Seller_ID"]
).value_counts()
# Out:
# Seller_ID
# True    50000
# Name: count, dtype: int64

# %%
order_items_clean["Order_ID"].isin(
    orders_clean["Order_ID"]
).value_counts()
# Out:
# Order_ID
# True    105953
# Name: count, dtype: int64

# %%
order_items_clean["Product_ID"].isin(
    products_clean["Product_ID"]
).value_counts()
# Out:
# Product_ID
# True    105953
# Name: count, dtype: int64

# %%
order_items_clean["Seller_ID"].isin(
    sellers_clean["Seller_ID"]
).value_counts()
# Out:
# Seller_ID
# True    105953
# Name: count, dtype: int64

# %%
customers_clean["Customer_ID"].nunique()
# Out:
# 2000

# %%
len(customers_clean)
# Out:
# 2000

# %%
print("Products:", products_clean["Product_ID"].nunique(), len(products_clean))
print("Sellers:", sellers_clean["Seller_ID"].nunique(), len(sellers_clean))
print("Orders:", orders_clean["Order_ID"].nunique(), len(orders_clean))
# Out:
# Products: 420 420
# Sellers: 100 100
# Orders: 50000 50000

# %%
order_items_clean.duplicated(subset=["Order_ID", "Product_ID"]).sum()
# Out:
# np.int64(0)

# %%
total_sales = order_items_clean["Sales"].sum()
print("Total Sales:", total_sales)

total_cost = order_items_clean["Cost"].sum()
print("Total cost:", total_cost)

total_profit = order_items_clean["Profit"].sum()
print("Total Profit:", total_profit)
# Out:
# Total Sales: 2107565604.0
# Total cost: 1472412030.85
# Total Profit: 635153573.15

# %%
profit_margin = (total_profit/total_sales)*100
print("Profit Margin:", profit_margin)
# Out:
# Profit Margin: 30.136835216162506

# %%
total_orders = orders_clean["Order_ID"].nunique()
print("Total orders:", total_orders)
# Out:
# Total orders: 50000

# %%
total_customers = customers_clean["Customer_ID"].nunique()
print("Total customers:", total_customers)
# Out:
# Total customers: 2000

# %%
avg_order_per_customer = (total_orders/total_customers)
print("average order per customer:", avg_order_per_customer)
# Out:
# average order per customer: 25.0

# %%
category_analysis = order_items_clean.merge(products_clean[["Product_ID", "Category"]], on = "Product_ID", how="left")

# %%
category_analysis.shape
# Out:
# (105953, 10)

# %%
category_analysis["Category"].isnull().sum()
# Out:
# np.int64(0)

# %%
category_summary = category_analysis.groupby("Category").agg(
                                             total_sales = ("Sales","sum"),
                                             total_cost = ("Cost","sum"),
                                             total_profit = ("Profit", "sum"),
                                             total_quantity = ("Quantity", "sum")
                                             ).reset_index()

# %%
category_summary
# Out:
#                  Category   total_sales    total_cost  total_profit  \
# 0  Beauty & Personal Care  6.638252e+07  4.677470e+07  1.960781e+07
# 1                   Books  3.044337e+07  2.154134e+07  8.902038e+06
# 2             Electronics  1.013188e+09  7.029123e+08  3.102759e+08
# 3                 Fashion  1.309160e+08  9.294767e+07  3.796829e+07
# 4          Home & Kitchen  3.228456e+08  2.311535e+08  9.169219e+07
# 5         Office Supplies  2.834373e+08  1.989330e+08  8.450431e+07
# 6        Sports & Fitness  2.603527e+08  1.781496e+08  8.220308e+07
#
#    total_quantity
# 0           37919
# 1           37540
# 2           38225
# 3           38169
# 4           37262
# 5           37697
# 6           37901

# %%
category_summary["Profit_margin"]=(category_summary["total_profit"]/category_summary["total_sales"])*100

# %%
category_summary.sort_values("Profit_margin", ascending=False)
# Out:
#                  Category   total_sales    total_cost  total_profit  \
# 6        Sports & Fitness  2.603527e+08  1.781496e+08  8.220308e+07
# 2             Electronics  1.013188e+09  7.029123e+08  3.102759e+08
# 5         Office Supplies  2.834373e+08  1.989330e+08  8.450431e+07
# 0  Beauty & Personal Care  6.638252e+07  4.677470e+07  1.960781e+07
# 1                   Books  3.044337e+07  2.154134e+07  8.902038e+06
# 3                 Fashion  1.309160e+08  9.294767e+07  3.796829e+07
# 4          Home & Kitchen  3.228456e+08  2.311535e+08  9.169219e+07
#
#    total_quantity  Profit_margin
# 6           37901      31.573742
# 2           38225      30.623715
# 5           37697      29.814111
# 0           37919      29.537613
# 1           37540      29.241298
# 3           38169      29.002034
# 4           37262      28.401248

# %%
category_summary.sort_values("total_sales", ascending=False)[["Category", "total_sales", "total_profit", "Profit_margin"]]
# Out:
#                  Category   total_sales  total_profit  Profit_margin
# 2             Electronics  1.013188e+09  3.102759e+08      30.623715
# 4          Home & Kitchen  3.228456e+08  9.169219e+07      28.401248
# 5         Office Supplies  2.834373e+08  8.450431e+07      29.814111
# 6        Sports & Fitness  2.603527e+08  8.220308e+07      31.573742
# 3                 Fashion  1.309160e+08  3.796829e+07      29.002034
# 0  Beauty & Personal Care  6.638252e+07  1.960781e+07      29.537613
# 1                   Books  3.044337e+07  8.902038e+06      29.241298

# %%
subcategory_analysis = order_items_clean.merge(
    products_clean[["Product_ID", "Category", "Subcategory"]],
    on="Product_ID",
    how="left"
)

# %%
subcategory_analysis.shape
# Out:
# (105953, 11)

# %%
subcategory_analysis["Category"].isnull().sum()
# Out:
# np.int64(0)

# %%
subcategory_analysis["Subcategory"].isnull().sum()
# Out:
# np.int64(0)

# %%
subcategory_summary = subcategory_analysis.groupby(
    ["Category", "Subcategory"]
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Cost=("Cost", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum")
).reset_index()

# %%
subcategory_summary
# Out:
#                   Category         Subcategory  Total_Sales    Total_Cost  \
# 0   Beauty & Personal Care            Haircare   15297198.0  1.051985e+07
# 1   Beauty & Personal Care              Makeup   16981772.0  1.235887e+07
# 2   Beauty & Personal Care       Personal Care   12129193.0  8.584512e+06
# 3   Beauty & Personal Care            Skincare   21974352.0  1.531147e+07
# 4                    Books            Academic   11374688.0  8.070827e+06
# 5                    Books            Children    3946754.0  2.664685e+06
# 6                    Books             Fiction    5693929.0  3.944767e+06
# 7                    Books         Non-Fiction    9428003.0  6.861057e+06
# 8              Electronics         Accessories   25984240.0  1.789793e+07
# 9              Electronics               Audio  103516928.0  7.211341e+07
# 10             Electronics             Laptops  523008552.0  3.697167e+08
# 11             Electronics         Smartphones  360678441.0  2.431842e+08
# ...

# %%
subcategory_summary["Profit_Margin"] = (
    subcategory_summary["Total_Profit"]
    / subcategory_summary["Total_Sales"]
) * 100

# %%
subcategory_summary.sort_values(
    "Profit_Margin",
    ascending=False
)
# Out:
#                   Category         Subcategory  Total_Sales    Total_Cost  \
# 26        Sports & Fitness             Outdoor   59914127.0  3.888032e+07
# 24        Sports & Fitness         Accessories   26308111.0  1.754833e+07
# 11             Electronics         Smartphones  360678441.0  2.431842e+08
# 5                    Books            Children    3946754.0  2.664685e+06
# 27        Sports & Fitness          Sportswear   28011658.0  1.893927e+07
# 15                 Fashion               Women   31504274.0  2.153593e+07
# 0   Beauty & Personal Care            Haircare   15297198.0  1.051985e+07
# 8              Electronics         Accessories   25984240.0  1.789793e+07
# 19          Home & Kitchen             Storage   34593827.0  2.396117e+07
# 6                    Books             Fiction    5693929.0  3.944767e+06
# 20         Office Supplies    Office Furniture  107303246.0  7.471475e+07
# 9              Electronics               Audio  103516928.0  7.211341e+07
# ...

# %%
product_analysis = order_items_clean.merge(
    products_clean[["Product_ID", "Product_Name", "Category", "Subcategory", "Brand"]],
    on="Product_ID",
    how="left"
)

# %%
product_analysis.shape
# Out:
# (105953, 13)

# %%
product_analysis["Product_Name"].isnull().sum()
# Out:
# np.int64(0)

# %%
product_summary = product_analysis.groupby(
    ["Product_ID", "Product_Name", "Category", "Subcategory", "Brand"]
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Cost=("Cost", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum")
).reset_index()

# %%
top_products_sales = product_summary.sort_values(
    "Total_Sales",
    ascending=False
)

# %%
top_products_sales.head(10)
# Out:
#    Product_ID              Product_Name     Category  Subcategory      Brand  \
# 8       P0009        Everday Laptops 09  Electronics      Laptops    Everday
# 6       P0007          Vista Laptops 07  Electronics      Laptops      Vista
# 13      P0014           Aero Laptops 14  Electronics      Laptops       Aero
# 12      P0013      HomeCraft Laptops 13  Electronics      Laptops  HomeCraft
# 7       P0008       CorePlus Laptops 08  Electronics      Laptops   CorePlus
# 27      P0028   CorePlus Smartphones 13  Electronics  Smartphones   CorePlus
# 20      P0021   NovaTech Smartphones 06  Electronics  Smartphones   NovaTech
# 17      P0018   CorePlus Smartphones 03  Electronics  Smartphones   CorePlus
# 15      P0016  PrimeLine Smartphones 01  Electronics  Smartphones  PrimeLine
# 1       P0002      UrbanEdge Laptops 02  Electronics      Laptops  UrbanEdge
#
#     Total_Sales   Total_Cost  Total_Profit  Total_Quantity
# 8    54272426.0  40472544.00   13799882.00             687
# ...

# %%
top_products_profit = product_summary.sort_values(
    "Total_Profit",
    ascending=False
)

# %%
top_products_profit.head(10)
# Out:
#    Product_ID              Product_Name     Category  Subcategory      Brand  \
# 6       P0007          Vista Laptops 07  Electronics      Laptops      Vista
# 12      P0013      HomeCraft Laptops 13  Electronics      Laptops  HomeCraft
# 15      P0016  PrimeLine Smartphones 01  Electronics  Smartphones  PrimeLine
# 1       P0002      UrbanEdge Laptops 02  Electronics      Laptops  UrbanEdge
# 8       P0009        Everday Laptops 09  Electronics      Laptops    Everday
# 10      P0011       NovaTech Laptops 11  Electronics      Laptops   NovaTech
# 25      P0026  PrimeLine Smartphones 11  Electronics  Smartphones  PrimeLine
# 20      P0021   NovaTech Smartphones 06  Electronics  Smartphones   NovaTech
# 7       P0008       CorePlus Laptops 08  Electronics      Laptops   CorePlus
# 16      P0017      Vista Smartphones 02  Electronics  Smartphones      Vista
#
#     Total_Sales   Total_Cost  Total_Profit  Total_Quantity
# 6    46336444.0  25697346.00   20639098.00             600
# ...

# %%
product_summary["Profit_Margin"] = (
    product_summary["Total_Profit"]
    / product_summary["Total_Sales"]
) * 100

top_margin_products = product_summary.sort_values(
    "Profit_Margin",
    ascending=False
)

top_margin_products.head(10)
# Out:
#     Product_ID                      Product_Name                Category  \
# 15       P0016          PrimeLine Smartphones 01             Electronics
# 183      P0184                  Aero Skincare 04  Beauty & Personal Care
# 239      P0240              BrightLife Makeup 15  Beauty & Personal Care
# 69       P0070  BrightLife Kitchen Appliances 10          Home & Kitchen
# 77       P0078             CorePlus Furniture 03          Home & Kitchen
# 1        P0002              UrbanEdge Laptops 02             Electronics
# 366      P0367        Vista Fitness Equipment 07        Sports & Fitness
# 12       P0013              HomeCraft Laptops 13             Electronics
# 197      P0198              CorePlus Haircare 03  Beauty & Personal Care
# 297      P0298              CorePlus Children 13                   Books
#
#             Subcategory       Brand  Total_Sales   Total_Cost  Total_Profit  \
# 15          Smartphones   PrimeLine   35158410.0  19046605.72   16111804.28
# ...

# %%
customer_analysis = order_items_clean.merge(
    orders_clean[["Order_ID", "Customer_ID", "Order_Date"]],
    on="Order_ID",
    how="left"
)

customer_analysis.shape
# Out:
# (105953, 11)

# %%
customer_analysis["Customer_ID"].isnull().sum()
# Out:
# np.int64(0)

# %%
customer_summary = customer_analysis.groupby("Customer_ID").agg(
    Total_Orders=("Order_ID", "nunique"),
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum")
).reset_index()

# %%
customer_summary.shape
# Out:
# (2000, 5)

# %%
top_customers_sales = customer_summary.sort_values(
    "Total_Sales",
    ascending=False
)

top_customers_sales.head(10)
# Out:
#      Customer_ID  Total_Orders  Total_Sales  Total_Profit  Total_Quantity
# 1562      C01563            30    2436182.0     786725.66             206
# 1214      C01215            34    2218266.0     657229.97             179
# 397       C00398            27    2183761.0     687831.12             147
# 1255      C01256            31    2182545.0     614892.06             187
# 1677      C01678            37    2176229.0     505761.90             210
# 478       C00479            30    2171074.0     680767.34             186
# 1444      C01445            27    2165343.0     686781.47             146
# 1879      C01880            23    2145118.0     598369.82             142
# 1394      C01395            26    2131464.0     651783.94             188
# 733       C00734            29    2112479.0     517247.02             184

# %%
top_customers_profit = customer_summary.sort_values(
    "Total_Profit",
    ascending=False
)

top_customers_profit.head(10)
# Out:
#      Customer_ID  Total_Orders  Total_Sales  Total_Profit  Total_Quantity
# 1562      C01563            30    2436182.0     786725.66             206
# 172       C00173            27    2059416.0     752843.25             152
# 117       C00118            28    1954560.0     732428.35             173
# 613       C00614            35    2061446.0     714146.98             208
# 889       C00890            22    2095110.0     706855.72             144
# 1611      C01612            27    2089560.0     704441.41             145
# 1855      C01856            29    1913522.0     691487.60             142
# 397       C00398            27    2183761.0     687831.12             147
# 1444      C01445            27    2165343.0     686781.47             146
# 1323      C01324            27    2037419.0     680771.82             150

# %%
customer_summary["Average_Order_Value"] = (customer_summary["Total_Sales"]/customer_summary["Total_Orders"])

# %%
top_customers_aov = customer_summary.sort_values("Average_Order_Value",ascending=False)

# %%
top_customers_aov.head(10)
# Out:
#      Customer_ID  Total_Orders  Total_Sales  Total_Profit  Total_Quantity  \
# 889       C00890            22    2095110.0     706855.72             144
# 1879      C01880            23    2145118.0     598369.82             142
# 332       C00333            19    1626492.0     515597.43             111
# 1260      C01261            19    1602420.0     510597.55             122
# 1394      C01395            26    2131464.0     651783.94             188
# 1562      C01563            30    2436182.0     786725.66             206
# 1622      C01623            22    1783182.0     598462.99             111
# 397       C00398            27    2183761.0     687831.12             147
# 1444      C01445            27    2165343.0     686781.47             146
# 773       C00774            19    1517289.0     490919.87             145
#
#       Average_Order_Value
# 889          95232.272727
# 1879         93266.000000
# 332          85604.842105
# 1260         84337.894737
# ...

# %%
customer_summary["Profit_Margin"] = (
    customer_summary["Total_Profit"]
    / customer_summary["Total_Sales"]
) * 100

# %%
top_customers_margin = customer_summary.sort_values(
    "Profit_Margin",
    ascending=False
)

# %%
top_customers_margin.head(10)
# Out:
#      Customer_ID  Total_Orders  Total_Sales  Total_Profit  Total_Quantity  \
# 1079      C01080            16     861973.0     361550.02              79
# 789       C00790            20    1018095.0     416260.50             101
# 1823      C01824            23    1155517.0     466848.48             145
# 529       C00530            19     783513.0     315282.98              91
# 770       C00771            25    1454744.0     578119.93             140
# 627       C00628            17     603051.0     237409.74              85
# 444       C00445            19    1168539.0     457369.53             111
# 1462      C01463            27    1556464.0     608990.80             130
# 1230      C01231            22     645725.0     252045.97             116
# 1123      C01124            23     935322.0     363746.54             128
#
#       Average_Order_Value  Profit_Margin
# 1079         53873.312500      41.944472
# 789          50904.750000      40.886214
# ...

# %%
order_status_summary = orders_clean["Order_Status"].value_counts()

# %%
order_status_summary
# Out:
# Order_Status
# Completed    42954
# Cancelled     2512
# Returned      2487
# Pending       2047
# Name: count, dtype: int64

# %%
order_status_percentage = (
    orders_clean["Order_Status"]
    .value_counts(normalize=True)
    * 100
)

# %%
order_status_percentage
# Out:
# Order_Status
# Completed    85.908
# Cancelled     5.024
# Returned      4.974
# Pending       4.094
# Name: proportion, dtype: float64

# %%
cancellation_rate = (
    (orders_clean["Order_Status"] == "Cancelled").sum()
    / len(orders_clean)
) * 100

# %%
return_rate = (
    (orders_clean["Order_Status"] == "Returned").sum()
    / len(orders_clean)
) * 100

# %%
print(f"Cancellation Rate: {cancellation_rate:.2f}%")
print(f"Return Rate: {return_rate:.2f}%")
# Out:
# Cancellation Rate: 5.02%
# Return Rate: 4.97%

# %%
orders_clean["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Wallet         8542
# Credit Card    8416
# Debit Card     8363
# UPI            8261
# Net Banking    8259
# COD            8159
# Name: count, dtype: int64

# %%
orders_clean["Payment_Method"].value_counts(normalize=True) * 100
# Out:
# Payment_Method
# Wallet         17.084
# Credit Card    16.832
# Debit Card     16.726
# UPI            16.522
# Net Banking    16.518
# COD            16.318
# Name: proportion, dtype: float64

# %%
payment_status = pd.crosstab(
    orders_clean["Payment_Method"],
    orders_clean["Order_Status"]
)

payment_status
# Out:
# Order_Status    Cancelled  Completed  Pending  Returned
# Payment_Method
# COD                   404       7068      303       384
# Credit Card           440       7245      312       419
# Debit Card            429       7181      349       404
# Net Banking           395       7056      374       434
# UPI                   424       7074      355       408
# Wallet                420       7330      354       438

# %%
payment_status_pct = pd.crosstab(
    orders_clean["Payment_Method"],
    orders_clean["Order_Status"],
    normalize="index"
) * 100

# %%
payment_status_pct.round(2)
# Out:
# Order_Status    Cancelled  Completed  Pending  Returned
# Payment_Method
# COD                  4.95      86.63     3.71      4.71
# Credit Card          5.23      86.09     3.71      4.98
# Debit Card           5.13      85.87     4.17      4.83
# Net Banking          4.78      85.43     4.53      5.25
# UPI                  5.13      85.63     4.30      4.94
# Wallet               4.92      85.81     4.14      5.13

# %%
orders_clean["Shipping_Mode"].value_counts()
# Out:
# Shipping_Mode
# Same Day    16830
# Standard    16595
# Express     16575
# Name: count, dtype: int64

# %%
orders_clean["Shipping_Mode"].value_counts(normalize=True) * 100
# Out:
# Shipping_Mode
# Same Day    33.66
# Standard    33.19
# Express     33.15
# Name: proportion, dtype: float64

# %%
shipping_status = pd.crosstab(
    orders_clean["Shipping_Mode"],
    orders_clean["Order_Status"]
)

shipping_status
# Out:
# Order_Status   Cancelled  Completed  Pending  Returned
# Shipping_Mode
# Express              874      14222      669       810
# Same Day             799      14492      698       841
# Standard             839      14240      680       836

# %%
shipping_status_pct = pd.crosstab(
    orders_clean["Shipping_Mode"],
    orders_clean["Order_Status"],
    normalize="index"
) * 100

# %%
shipping_status_pct.round(2)
# Out:
# Order_Status   Cancelled  Completed  Pending  Returned
# Shipping_Mode
# Express             5.27      85.80     4.04      4.89
# Same Day            4.75      86.11     4.15      5.00
# Standard            5.06      85.81     4.10      5.04

# %%
# %whos
# Out:
# Variable                  Type         Data/Info
# ------------------------------------------------
# avg_order_per_customer    float        25.0
# cancellation_rate         float64      5.024
# category_analysis         DataFrame    Shape: (105953, 10)
# category_summary          DataFrame    Shape: (7, 6)
# customer_analysis         DataFrame    Shape: (105953, 11)
# customer_summary          DataFrame    Shape: (2000, 7)
# customers                 DataFrame    Shape: (2000, 9)
# customers_clean           DataFrame    Shape: (2000, 9)
# np                        module       <module 'numpy' from '/Li<...>kages/numpy/__init__.py'>
# order_items               DataFrame    Shape: (105953, 9)
# order_items_clean         DataFrame    Shape: (105953, 9)
# order_status_percentage   Series       Shape: (4,)
# order_status_summary      Series       Shape: (4,)
# orders                    DataFrame    Shape: (50000, 7)
# orders_clean              DataFrame    Shape: (50000, 7)
# ...

# %%
product_analysis.columns
# Out:
# Index(['Order_ID', 'Product_ID', 'Seller_ID', 'Quantity', 'Discount', 'Sales',
#        'Cost', 'Profit', 'Order_Status', 'Product_Name', 'Category',
#        'Subcategory', 'Brand'],
#       dtype='str')

# %%
seller_summary = product_analysis.groupby("Seller_ID").agg(
    Total_Sales=("Sales", "sum"),
    Total_Cost=("Cost", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum")
).reset_index()

# %%
top_sellers_sales = seller_summary.sort_values(
    "Total_Sales",
    ascending=False
)

# %%
top_sellers_sales.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity
# 47     S0048   24173081.0  17005850.54    7167230.46            2960
# 56     S0057   23919107.0  16542891.49    7376215.51            2934
# 35     S0036   23718035.0  16879012.18    6839022.82            2811
# 53     S0054   23551003.0  16709228.33    6841774.67            2859
# 98     S0099   23441296.0  16437413.52    7003882.48            2826
# 49     S0050   23400216.0  16558420.59    6841795.41            2810
# 82     S0083   23382847.0  16283753.36    7099093.64            2787
# 45     S0046   23299104.0  16111130.57    7187973.43            2910
# 96     S0097   23290057.0  16120316.75    7169740.25            2619
# 15     S0016   23176626.0  16123390.19    7053235.81            2853

# %%
top_sellers_profit = seller_summary.sort_values(
    "Total_Profit",
    ascending=False
)

# %%
top_sellers_profit.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity
# 56     S0057   23919107.0  16542891.49    7376215.51            2934
# 45     S0046   23299104.0  16111130.57    7187973.43            2910
# 22     S0023   22302308.0  15119807.61    7182500.39            2889
# 96     S0097   23290057.0  16120316.75    7169740.25            2619
# 47     S0048   24173081.0  17005850.54    7167230.46            2960
# 82     S0083   23382847.0  16283753.36    7099093.64            2787
# 15     S0016   23176626.0  16123390.19    7053235.81            2853
# 98     S0099   23441296.0  16437413.52    7003882.48            2826
# 85     S0086   23126656.0  16185272.90    6941383.10            2797
# 89     S0090   22103340.0  15193483.00    6909857.00            2775

# %%
seller_summary["Profit_Margin"] = (
    seller_summary["Total_Profit"]
    / seller_summary["Total_Sales"]
) * 100

# %%
top_sellers_margin = seller_summary.sort_values(
    "Profit_Margin",
    ascending=False
)

# %%
top_sellers_margin.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity  \
# 61     S0062   20452985.0  13784234.35    6668750.65            2618
# 22     S0023   22302308.0  15119807.61    7182500.39            2889
# 86     S0087   20517989.0  14019327.18    6498661.82            2590
# 25     S0026   19462985.0  13349353.63    6113631.37            2649
# 18     S0019   21502171.0  14759086.04    6743084.96            2603
# 52     S0053   21576025.0  14821518.84    6754506.16            2406
# 89     S0090   22103340.0  15193483.00    6909857.00            2775
# 27     S0028   22002077.0  15125363.64    6876713.36            2687
# 7      S0008   19842819.0  13666953.06    6175865.94            2561
# 36     S0037   21389914.0  14741335.88    6648578.12            2540
#
#     Profit_Margin
# 61      32.605268
# 22      32.205189
# 86      31.672996
# 25      31.411581
# 18      31.360019
# 52      31.305610
# 89      31.261597
# 27      31.254837
# 7       31.123934
# ...

# %%
seller_orders = product_analysis.groupby("Seller_ID")["Order_ID"].nunique().reset_index(
    name="Total_Orders"
)

# %%
seller_orders = seller_orders.sort_values(
    "Total_Orders",
    ascending=False
)

# %%
seller_orders.head(10)
# Out:
#    Seller_ID  Total_Orders
# 47     S0048           553
# 63     S0064           550
# 41     S0042           550
# 9      S0010           543
# 53     S0054           540
# 98     S0099           539
# 45     S0046           536
# 56     S0057           535
# 35     S0036           534
# 1      S0002           534

# %%
seller_performance = seller_summary.merge(
    seller_orders,
    on="Seller_ID"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 seller_performance = seller_summary.merge(
#       2     seller_orders,
#       3     on="Seller_ID"
#       4 )
#
# NameError: name 'seller_summary' is not defined

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
import os

os.listdir()
# Out:
# ['customers.csv',
#  'products.csv',
#  'orders.csv',
#  'Untitled.ipynb',
#  'sellers.csv',
#  '.ipynb_checkpoints',
#  'order_items.csv']

# %%
import pandas as pd
import numpy as np

customers = pd.read_csv("customers.csv")
products = pd.read_csv("products.csv")
orders = pd.read_csv("orders.csv")
sellers = pd.read_csv("sellers.csv")
order_items = pd.read_csv("order_items.csv")

# %%
print("Customers:", customers.shape)
print("Products:", products.shape)
print("Orders:", orders.shape)
print("Sellers:", sellers.shape)
print("Order Items:", order_items.shape)
# Out:
# Customers: (2000, 9)
# Products: (420, 7)
# Orders: (50000, 7)
# Sellers: (100, 4)
# Order Items: (105953, 9)

# %%
print("Customers:")
print(customers.info())

print("\nProducts:")
print(products.info())

print("\nOrders:")
print(orders.info())

print("\nSellers:")
print(sellers.info())

print("\nOrder Items:")
print(order_items.info())
# Out:
# Customers:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       2000 non-null   str
#  1   Customer_Name     2000 non-null   str
#  2   Gender            2000 non-null   str
#  3   Age               2000 non-null   int64
#  4   Customer_Segment  2000 non-null   str
#  5   City              2000 non-null   str
#  6   State             2000 non-null   str
#  7   Region            2000 non-null   str
#  8   Signup_Date       2000 non-null   str
# dtypes: int64(1), str(8)
# memory usage: 140.8 KB
# None
#
# Products:
# <class 'pandas.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    420 non-null    str
#  1   Product_Name  420 non-null    str
#  2   Category      420 non-null    str
# ...

# %%
customers_clean = customers.copy()
products_clean = products.copy()
orders_clean = orders.copy()
sellers_clean = sellers.copy()
order_items_clean = order_items.copy()

# %%
customers_clean["Signup_Date"] = pd.to_datetime(
    customers_clean["Signup_Date"]
)

orders_clean["Order_Date"] = pd.to_datetime(
    orders_clean["Order_Date"]
)

# %%
print(customers_clean.dtypes)
print(orders_clean.dtypes)
# Out:
# Customer_ID                    str
# Customer_Name                  str
# Gender                         str
# Age                          int64
# Customer_Segment               str
# City                           str
# State                          str
# Region                         str
# Signup_Date         datetime64[us]
# dtype: object
# Order_ID                     str
# Order_Date        datetime64[us]
# Customer_ID                  str
# Seller_ID                    str
# Order_Status                 str
# Payment_Method               str
# Shipping_Mode                str
# dtype: object

# %%
product_analysis = order_items_clean.merge(
    products_clean[
        [
            "Product_ID",
            "Product_Name",
            "Category",
            "Subcategory",
            "Brand"
        ]
    ],
    on="Product_ID",
    how="left"
)

# %%
print(product_analysis.shape)
print(product_analysis.columns)
# Out:
# (105953, 13)
# Index(['Order_ID', 'Product_ID', 'Seller_ID', 'Quantity', 'Discount', 'Sales',
#        'Cost', 'Profit', 'Order_Status', 'Product_Name', 'Category',
#        'Subcategory', 'Brand'],
#       dtype='str')

# %%
product_analysis = order_items_clean.merge(
    products_clean[
        [
            "Product_ID",
            "Product_Name",
            "Category",
            "Subcategory",
            "Brand"
        ]
    ],
    on="Product_ID",
    how="left"
)

# %%
print(product_analysis.shape)
print(product_analysis.columns)
# Out:
# (105953, 13)
# Index(['Order_ID', 'Product_ID', 'Seller_ID', 'Quantity', 'Discount', 'Sales',
#        'Cost', 'Profit', 'Order_Status', 'Product_Name', 'Category',
#        'Subcategory', 'Brand'],
#       dtype='str')

# %%
print("Total Sales:", product_analysis["Sales"].sum())
print("Total Cost:", product_analysis["Cost"].sum())
print("Total Profit:", product_analysis["Profit"].sum())
print("Total Quantity:", product_analysis["Quantity"].sum())
# Out:
# Total Sales: 2107294674.0
# Total Cost: 1472230830.85
# Total Profit: 635063843.15
# Total Quantity: 264713

# %%
seller_summary = product_analysis.groupby("Seller_ID").agg(
    Total_Sales=("Sales", "sum"),
    Total_Cost=("Cost", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum")
).reset_index()

# %%
seller_orders = product_analysis.groupby("Seller_ID")["Order_ID"].nunique().reset_index(
    name="Total_Orders"
)

# %%
seller_performance = seller_summary.merge(
    seller_orders,
    on="Seller_ID"
)

# %%
seller_performance["Profit_Per_Order"] = (
    seller_performance["Total_Profit"]
    / seller_performance["Total_Orders"]
)

# %%
top_sellers_profit_per_order = seller_performance.sort_values(
    "Profit_Per_Order",
    ascending=False
)

# %%
top_sellers_profit_per_order.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity  \
# 96     S0097   23287352.0  16118516.75    7168835.25            2619
# 52     S0053   21574720.0  14820618.84    6754101.16            2406
# 58     S0059   21447202.0  14846355.90    6600846.10            2449
# 22     S0023   22302308.0  15119807.61    7182500.39            2889
# 16     S0017   21850127.0  15100899.66    6749227.34            2607
# 85     S0086   23120651.0  16181372.90    6939278.10            2797
# 82     S0083   23381007.0  16282553.36    7098453.64            2787
# 56     S0057   23917672.0  16541991.49    7375680.51            2934
# 84     S0085   22344108.0  15688333.96    6655774.04            2593
# 89     S0090   22100960.0  15191683.00    6909277.00            2775
#
#     Total_Orders  Profit_Per_Order
# 96           487      14720.400924
# 52           463      14587.691490
# 58           467      14134.574090
# 22           515      13946.602699
# ...

# %%
seller_performance["Average_Order_Value"] = (
    seller_performance["Total_Sales"]
    / seller_performance["Total_Orders"]
)

# %%
top_sellers_aov = seller_performance.sort_values(
    "Average_Order_Value",
    ascending=False
)

# %%
top_sellers_aov.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity  \
# 96     S0097   23287352.0  16118516.75    7168835.25            2619
# 52     S0053   21574720.0  14820618.84    6754101.16            2406
# 85     S0086   23120651.0  16181372.90    6939278.10            2797
# 84     S0085   22344108.0  15688333.96    6655774.04            2593
# 58     S0059   21447202.0  14846355.90    6600846.10            2449
# 65     S0066   20488400.0  14356182.88    6132217.12            2316
# 82     S0083   23381007.0  16282553.36    7098453.64            2787
# 16     S0017   21850127.0  15100899.66    6749227.34            2607
# 49     S0050   23400216.0  16558420.59    6841795.41            2810
# 12     S0013   21538183.0  15166217.61    6371965.39            2572
#
#     Total_Orders  Profit_Per_Order  Average_Order_Value
# 96           487      14720.400924         47817.971253
# 52           463      14587.691490         46597.667387
# ...

# %%
seller_performance["Avg_Quantity_Per_Order"] = (
    seller_performance["Total_Quantity"]
    / seller_performance["Total_Orders"]
)

# %%
top_sellers_quantity_per_order = seller_performance.sort_values(
    "Avg_Quantity_Per_Order",
    ascending=False
)

# %%
top_sellers_quantity_per_order.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity  \
# 30     S0031   22184922.0  15460217.40    6724704.60            2895
# 85     S0086   23120651.0  16181372.90    6939278.10            2797
# 22     S0023   22302308.0  15119807.61    7182500.39            2889
# 28     S0029   22951901.0  16075149.67    6876751.33            2905
# 37     S0038   21697183.0  15300589.73    6396593.27            2876
# 1      S0002   22542991.0  15790032.73    6752958.27            2948
# 4      S0005   21567027.0  15286286.14    6280740.86            2787
# 91     S0092   22837221.0  16087332.00    6749889.00            2857
# 89     S0090   22100960.0  15191683.00    6909277.00            2775
# 56     S0057   23917672.0  16541991.49    7375680.51            2934
#
#     Total_Orders  Profit_Per_Order  Average_Order_Value  \
# 30           511      13159.891585         43414.720157
# 85           498      13934.293373         46427.010040
# ...

# %%
seller_performance["Sales_Per_Unit"] = (
    seller_performance["Total_Sales"]
    / seller_performance["Total_Quantity"]
)

# %%
top_sellers_sales_per_unit = seller_performance.sort_values(
    "Sales_Per_Unit",
    ascending=False
)

# %%
top_sellers_sales_per_unit.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity  \
# 52     S0053   21574720.0  14820618.84    6754101.16            2406
# 96     S0097   23287352.0  16118516.75    7168835.25            2619
# 65     S0066   20488400.0  14356182.88    6132217.12            2316
# 58     S0059   21447202.0  14846355.90    6600846.10            2449
# 84     S0085   22344108.0  15688333.96    6655774.04            2593
# 67     S0068   20955431.0  14615118.91    6340312.09            2432
# 14     S0015   21618828.0  15030204.93    6588623.07            2539
# 35     S0036   23714135.0  16876612.18    6837522.82            2811
# 36     S0037   21385659.0  14738635.88    6647023.12            2540
# 82     S0083   23381007.0  16282553.36    7098453.64            2787
#
#     Total_Orders  Profit_Per_Order  Average_Order_Value  \
# 52           463      14587.691490         46597.667387
# 96           487      14720.400924         47817.971253
# ...

# %%
seller_performance["Profit_Per_Unit"] = (
    seller_performance["Total_Profit"]
    / seller_performance["Total_Quantity"]
)

# %%
top_sellers_profit_per_unit = seller_performance.sort_values(
    "Profit_Per_Unit",
    ascending=False
)

# %%
top_sellers_profit_per_unit.head(10)
# Out:
#    Seller_ID  Total_Sales   Total_Cost  Total_Profit  Total_Quantity  \
# 52     S0053   21574720.0  14820618.84    6754101.16            2406
# 96     S0097   23287352.0  16118516.75    7168835.25            2619
# 58     S0059   21447202.0  14846355.90    6600846.10            2449
# 65     S0066   20488400.0  14356182.88    6132217.12            2316
# 36     S0037   21385659.0  14738635.88    6647023.12            2540
# 67     S0068   20955431.0  14615118.91    6340312.09            2432
# 14     S0015   21618828.0  15030204.93    6588623.07            2539
# 18     S0019   21501686.0  14758786.04    6742899.96            2603
# 16     S0017   21850127.0  15100899.66    6749227.34            2607
# 84     S0085   22344108.0  15688333.96    6655774.04            2593
#
#     Total_Orders  Profit_Per_Order  Average_Order_Value  \
# 52           463      14587.691490         46597.667387
# 96           487      14720.400924         47817.971253
# ...

# %%
seller_discount = product_analysis.groupby("Seller_ID")["Discount"].mean().reset_index(
    name="Average_Discount"
)

# %%
top_sellers_discount = seller_discount.sort_values(
    "Average_Discount",
    ascending=False
)

# %%
top_sellers_discount.head(10)
# Out:
#    Seller_ID  Average_Discount
# 29     S0030          0.116841
# 98     S0099          0.115937
# 32     S0033          0.115438
# 91     S0092          0.115202
# 74     S0075          0.115176
# 40     S0041          0.114772
# 20     S0021          0.114735
# 92     S0093          0.114576
# 49     S0050          0.114415
# 4      S0005          0.114299

# %%
product_analysis["Discount_Band"] = pd.cut(
    product_analysis["Discount"],
    bins=[-0.01, 0.05, 0.10, 0.15, 0.20, 1],
    labels=[
        "0–5%",
        "5–10%",
        "10–15%",
        "15–20%",
        "20%+"
    ]
)

# %%
discount_analysis = product_analysis.groupby(
    "Discount_Band",
    observed=True
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Order_Items=("Order_ID", "count")
).reset_index()

# %%
discount_analysis["Profit_Margin"] = (
    discount_analysis["Total_Profit"]
    / discount_analysis["Total_Sales"]
    * 100
)

# %%
discount_analysis
# Out:
#   Discount_Band  Total_Sales  Total_Profit  Total_Quantity  Order_Items  \
# 0          0–5%  727098874.0  2.635699e+08           86191        34423
# 1         5–10%  481117906.0  1.538683e+08           58598        23507
# 2        10–15%  453528570.0  1.285297e+08           58443        23363
# 3        15–20%  230699099.0  5.272795e+07           31080        12431
# 4          20%+  214850225.0  3.636800e+07           30401        12229
#
#    Profit_Margin
# 0      36.249529
# 1      31.981403
# 2      28.339938
# 3      22.855725
# 4      16.927142

# %%
product_discount_impact = product_analysis.groupby(
    ["Product_ID", "Product_Name", "Category", "Subcategory", "Brand"]
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Average_Discount=("Discount", "mean")
).reset_index()

# %%
product_discount_impact["Profit_Margin"] = (
    product_discount_impact["Total_Profit"]
    / product_discount_impact["Total_Sales"]
    * 100
)

# %%
product_discount_impact_filtered = product_discount_impact[
    product_discount_impact["Total_Sales"] >= 500000
]

# %%
product_discount_impact_filtered.sort_values(
    "Profit_Margin",
    ascending=True
).head(10)
# Out:
#     Product_ID                Product_Name                Category  \
# 278      P0279         Everday Academic 09                   Books
# 91       P0092     UrbanEdge Home Decor 02          Home & Kitchen
# 334      P0335  Zenith Office Furniture 05         Office Supplies
# 39       P0040         BrightLife Audio 10             Electronics
# 3        P0004             Aero Laptops 04             Electronics
# 194      P0195          Zenith Skincare 15  Beauty & Personal Care
# 144      P0145             Zenith Women 10                 Fashion
# 119      P0120       BrightLife Storage 15          Home & Kitchen
# 112      P0113        HomeCraft Storage 08          Home & Kitchen
# 13       P0014             Aero Laptops 14             Electronics
#
#           Subcategory       Brand  Total_Sales  Total_Profit  Total_Quantity  \
# 278          Academic     Everday     598411.0      72694.30             619
# ...

# %%
category_discount_impact = product_analysis.groupby(
    "Category"
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Average_Discount=("Discount", "mean")
).reset_index()

# %%
category_discount_impact["Profit_Margin"] = (
    category_discount_impact["Total_Profit"]
    / category_discount_impact["Total_Sales"]
    * 100
)

# %%
category_discount_impact.sort_values(
    "Average_Discount",
    ascending=False
)
# Out:
#                  Category   Total_Sales  Total_Profit  Total_Quantity  \
# 2             Electronics  1.013188e+09  3.102759e+08           38225
# 3                 Fashion  1.309160e+08  3.796829e+07           38169
# 1                   Books  3.044337e+07  8.902038e+06           37540
# 4          Home & Kitchen  3.228456e+08  9.169219e+07           37262
# 0  Beauty & Personal Care  6.638252e+07  1.960781e+07           37919
# 6        Sports & Fitness  2.603527e+08  8.220308e+07           37901
# 5         Office Supplies  2.831664e+08  8.441458e+07           37697
#
#    Average_Discount  Profit_Margin
# 2          0.119201      30.623715
# 3          0.117333      29.002034
# 1          0.109292      29.241298
# 4          0.108701      28.401248
# 0          0.107864      29.537613
# 6          0.107213      31.573742
# 5          0.107160      29.810948

# %%
orders_clean["Year_Month"] = orders_clean["Order_Date"].dt.to_period("M")

# %%
monthly_orders = orders_clean.groupby(
    "Year_Month"
).agg(
    Total_Orders=("Order_ID", "nunique")
).reset_index()

# %%
monthly_financials = product_analysis.merge(
    orders_clean[["Order_ID", "Order_Date"]],
    on="Order_ID",
    how="left"
)

# %%
monthly_financials["Year_Month"] = (
    monthly_financials["Order_Date"].dt.to_period("M")
)

# %%
monthly_summary = monthly_financials.groupby(
    "Year_Month"
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum")
).reset_index()

# %%
monthly_summary
# Out:
#    Year_Month  Total_Sales  Total_Profit  Total_Quantity
# 0     2024-01   66127927.0   20375356.58            8162
# 1     2024-02   64307142.0   19625723.12            7775
# 2     2024-03   70190239.0   21144411.95            8736
# 3     2024-04   68988271.0   21104991.21            8116
# 4     2024-05   72221987.0   22605786.19            8793
# 5     2024-06   73744181.0   22162507.77            8872
# 6     2024-07   68292283.0   20992597.68            8282
# 7     2024-08   63901205.0   19472449.21            8187
# 8     2024-09   70328808.0   21619822.53            8373
# 9     2024-10   64004301.0   18475977.49            8766
# 10    2024-11   58603287.0   16331854.78            8007
# 11    2024-12   63912885.0   18063547.36            8418
# 12    2025-01   75618176.0   23015991.52            9153
# 13    2025-02   61435109.0   18514079.84            7520
# 14    2025-03   72050083.0   21707939.40            8658
# ...

# %%
monthly_summary = monthly_summary.merge(
    monthly_orders,
    on="Year_Month",
    how="left"
)

monthly_summary["Profit_Margin"] = (
    monthly_summary["Total_Profit"]
    / monthly_summary["Total_Sales"]
    * 100
)

monthly_summary
# Out:
#    Year_Month  Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# 0     2024-01   66127927.0   20375356.58            8162          1599
# 1     2024-02   64307142.0   19625723.12            7775          1453
# 2     2024-03   70190239.0   21144411.95            8736          1639
# 3     2024-04   68988271.0   21104991.21            8116          1537
# 4     2024-05   72221987.0   22605786.19            8793          1635
# 5     2024-06   73744181.0   22162507.77            8872          1679
# 6     2024-07   68292283.0   20992597.68            8282          1558
# 7     2024-08   63901205.0   19472449.21            8187          1544
# 8     2024-09   70328808.0   21619822.53            8373          1575
# 9     2024-10   64004301.0   18475977.49            8766          1644
# 10    2024-11   58603287.0   16331854.78            8007          1528
# 11    2024-12   63912885.0   18063547.36            8418          1641
# ...

# %%
monthly_summary["Month"] = monthly_summary["Year_Month"].dt.month

# %%
seasonal_summary = monthly_summary[
    ~(
        (monthly_summary["Year_Month"] == pd.Period("2026-08"))
    )
]

# %%
seasonal_summary = seasonal_summary.groupby(
    "Month"
).agg(
    Avg_Sales=("Total_Sales", "mean"),
    Avg_Profit=("Total_Profit", "mean"),
    Avg_Orders=("Total_Orders", "mean"),
    Avg_Quantity=("Total_Quantity", "mean"),
    Avg_Profit_Margin=("Profit_Margin", "mean")
).reset_index()

# %%
seasonal_summary
# Out:
#     Month     Avg_Sales    Avg_Profit   Avg_Orders  Avg_Quantity  \
# 0       1  6.947382e+07  2.110814e+07  1631.333333   8555.000000
# 1       2  6.167963e+07  1.875420e+07  1442.333333   7612.333333
# 2       3  6.929891e+07  2.099838e+07  1591.000000   8566.333333
# 3       4  6.549179e+07  2.001464e+07  1550.666667   8230.000000
# 4       5  6.925252e+07  2.118988e+07  1620.000000   8661.333333
# 5       6  7.021913e+07  2.144603e+07  1609.666667   8588.000000
# 6       7  6.824215e+07  2.104400e+07  1630.000000   8541.666667
# 7       8  6.626025e+07  2.029364e+07  1596.500000   8340.000000
# 8       9  6.944800e+07  2.124681e+07  1590.500000   8490.500000
# 9      10  6.311085e+07  1.822094e+07  1624.000000   8609.000000
# 10     11  6.351081e+07  1.783585e+07  1574.000000   8297.000000
# 11     12  6.626447e+07  1.876795e+07  1660.500000   8684.500000
#
#     Avg_Profit_Margin
# 0           30.381625
# 1           30.405879
# 2           30.310826
# 3           30.560369
# ...

# %%
segment_analysis = product_analysis.merge(
    orders_clean[["Order_ID", "Customer_ID"]],
    on="Order_ID",
    how="left"
)

# %%
segment_analysis = segment_analysis.merge(
    customers_clean[["Customer_ID", "Customer_Segment"]],
    on="Customer_ID",
    how="left"
)

# %%
segment_summary = segment_analysis.groupby(
    "Customer_Segment"
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Total_Order_Items=("Order_ID", "count"),
    Total_Orders=("Order_ID", "nunique"),
    Total_Customers=("Customer_ID", "nunique")
).reset_index()

# %%
segment_summary["Profit_Margin"] = (
    segment_summary["Total_Profit"]
    / segment_summary["Total_Sales"]
    * 100
)

segment_summary["Average_Order_Value"] = (
    segment_summary["Total_Sales"]
    / segment_summary["Total_Orders"]
)

# %%
segment_summary.sort_values(
    "Total_Profit",
    ascending=False
)
# Out:
#   Customer_Segment  Total_Sales  Total_Profit  Total_Quantity  \
# 2   Small Business  717550272.0  2.158197e+08           90693
# 0         Consumer  708749589.0  2.135621e+08           88452
# 1        Corporate  680994813.0  2.056821e+08           85568
#
#    Total_Order_Items  Total_Orders  Total_Customers  Profit_Margin  \
# 2              36279         17165              687      30.077290
# 0              35403         16732              670      30.132238
# 1              34271         16103              643      30.203175
#
#    Average_Order_Value
# 2         41803.103525
# 0         42358.928341
# 1         42289.934360

# %%
region_analysis = product_analysis.merge(
    orders_clean[["Order_ID", "Customer_ID"]],
    on="Order_ID",
    how="left"
)

# %%
region_analysis = region_analysis.merge(
    customers_clean[["Customer_ID", "Region"]],
    on="Customer_ID",
    how="left"
)

# %%
region_summary = region_analysis.groupby(
    "Region"
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Total_Order_Items=("Order_ID", "count"),
    Total_Orders=("Order_ID", "nunique"),
    Total_Customers=("Customer_ID", "nunique")
).reset_index()

# %%
region_summary["Profit_Margin"] = (
    region_summary["Total_Profit"]
    / region_summary["Total_Sales"]
    * 100
)

region_summary["Average_Order_Value"] = (
    region_summary["Total_Sales"]
    / region_summary["Total_Orders"]
)

# %%
region_summary.sort_values(
    "Total_Sales",
    ascending=False
)
# Out:
#   Region  Total_Sales  Total_Profit  Total_Quantity  Total_Order_Items  \
# 1  North  568672727.0  1.714842e+08           72203              28923
# 3   West  530143416.0  1.596064e+08           67632              27267
# 2  South  529346162.0  1.592396e+08           65265              25953
# 0   East  479132369.0  1.447337e+08           59613              23810
#
#    Total_Orders  Total_Customers  Profit_Margin  Average_Order_Value
# 1         13704              547      30.155161         41496.842309
# 3         12842              517      30.106264         41281.997820
# 2         12255              490      30.082315         43194.301265
# 0         11199              446      30.207458         42783.495759

# %%
status_financial_impact = product_analysis.groupby(
    "Order_Status"
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Cost=("Cost", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Order_Items=("Order_ID", "count"),
    Total_Orders=("Order_ID", "nunique")
).reset_index()

# %%
status_financial_impact["Sales_Share"] = (
    status_financial_impact["Total_Sales"]
    / total_sales * 100
)

status_financial_impact["Profit_Share"] = (
    status_financial_impact["Total_Profit"]
    / total_profit * 100
)

status_financial_impact
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 3
#       1 status_financial_impact["Sales_Share"] = (
#       2     status_financial_impact["Total_Sales"]
# ----> 3     / total_sales * 100
#       4 )
#       5
#       6 status_financial_impact["Profit_Share"] = (
#
# NameError: name 'total_sales' is not defined

# %%
status_financial_impact["Sales_Share"] = (
    status_financial_impact["Total_Sales"]
    / status_financial_impact["Total_Sales"].sum()
    * 100
)

status_financial_impact["Profit_Share"] = (
    status_financial_impact["Total_Profit"]
    / status_financial_impact["Total_Profit"].sum()
    * 100
)

status_financial_impact
# Out:
#   Order_Status   Total_Sales    Total_Cost  Total_Profit  Total_Quantity  \
# 0    Cancelled  1.064105e+08  7.407887e+07  3.233166e+07           13095
# 1    Completed  1.808453e+09  1.263440e+09  5.450131e+08          227643
# 2      Pending  8.706792e+07  6.115956e+07  2.590836e+07           10948
# 3     Returned  1.053635e+08  7.355276e+07  3.181073e+07           13027
#
#    Order_Items  Total_Orders  Sales_Share  Profit_Share
# 0         5286          2512     5.049627      5.091088
# 1        91071         42954    85.818692     85.820205
# 2         4366          2047     4.131739      4.079646
# 3         5230          2487     4.999941      5.009061

# %%
customer_order_frequency = orders_clean.groupby(
    "Customer_ID"
).agg(
    Total_Orders=("Order_ID", "nunique")
).reset_index()

customer_order_frequency["Customer_Type"] = np.where(
    customer_order_frequency["Total_Orders"] > 1,
    "Repeat Customer",
    "One-Time Customer"
)

customer_frequency_summary = customer_order_frequency.groupby(
    "Customer_Type"
).agg(
    Customers=("Customer_ID", "count")
).reset_index()

customer_frequency_summary["Percentage"] = (
    customer_frequency_summary["Customers"]
    / customer_frequency_summary["Customers"].sum()
    * 100
)

customer_frequency_summary
# Out:
#      Customer_Type  Customers  Percentage
# 0  Repeat Customer       2000       100.0

# %%
customer_order_frequency["Total_Orders"].describe()
# Out:
# count    2000.000000
# mean       25.000000
# std         4.977589
# min        12.000000
# 25%        22.000000
# 50%        25.000000
# 75%        28.000000
# max        44.000000
# Name: Total_Orders, dtype: float64

# %%
customer_order_frequency.sort_values(
    "Total_Orders",
    ascending=False
).head(10)
# Out:
#      Customer_ID  Total_Orders    Customer_Type
# 1006      C01007            44  Repeat Customer
# 788       C00789            42  Repeat Customer
# 145       C00146            42  Repeat Customer
# 1215      C01216            41  Repeat Customer
# 657       C00658            40  Repeat Customer
# 142       C00143            39  Repeat Customer
# 311       C00312            38  Repeat Customer
# 492       C00493            38  Repeat Customer
# 1619      C01620            38  Repeat Customer
# 299       C00300            38  Repeat Customer

# %%
customer_order_frequency["Frequency_Rank"] = (
    customer_order_frequency["Total_Orders"]
    .rank(method="first", ascending=False)
)

customer_order_frequency["Customer_Group"] = np.where(
    customer_order_frequency["Frequency_Rank"] <= 500,
    "Top 25% Customers",
    "Other Customers"
)

# %%
customer_value_analysis = product_analysis.merge(
    orders_clean[["Order_ID", "Customer_ID"]],
    on="Order_ID",
    how="left"
).merge(
    customer_order_frequency[
        ["Customer_ID", "Customer_Group"]
    ],
    on="Customer_ID",
    how="left"
)

# %%
customer_group_summary = customer_value_analysis.groupby(
    "Customer_Group"
).agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Total_Order_Items=("Order_ID", "count"),
    Total_Orders=("Order_ID", "nunique"),
    Total_Customers=("Customer_ID", "nunique")
).reset_index()

customer_group_summary["Profit_Margin"] = (
    customer_group_summary["Total_Profit"]
    / customer_group_summary["Total_Sales"]
    * 100
)

customer_group_summary["Sales_Share"] = (
    customer_group_summary["Total_Sales"]
    / customer_group_summary["Total_Sales"].sum()
    * 100
)

customer_group_summary
# Out:
#       Customer_Group   Total_Sales  Total_Profit  Total_Quantity  \
# 0    Other Customers  1.443600e+09  4.355176e+08          181299
# 1  Top 25% Customers  6.636942e+08  1.995463e+08           83414
#
#    Total_Order_Items  Total_Orders  Total_Customers  Profit_Margin  \
# 0              72530         34286             1500      30.168845
# 1              33423         15714              500      30.065994
#
#    Sales_Share
# 0    68.504918
# 1    31.495082

# %%
print(customers_clean.shape)
print(products_clean.shape)
print(orders_clean.shape)
print(sellers_clean.shape)
print(order_items_clean.shape)
# Out:
# (2000, 9)
# (420, 7)
# (50000, 8)
# (100, 4)
# (105953, 9)

# %%
print(
    customers_clean.columns.tolist(),
    products_clean.columns.tolist(),
    orders_clean.columns.tolist(),
    sellers_clean.columns.tolist(),
    order_items_clean.columns.tolist(),
    sep="\n\n"
)
# Out:
# ['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'Customer_Segment', 'City', 'State', 'Region', 'Signup_Date']
#
# ['Product_ID', 'Product_Name', 'Category', 'Subcategory', 'Brand', 'Unit_Cost', 'Unit_Price']
#
# ['Order_ID', 'Order_Date', 'Customer_ID', 'Seller_ID', 'Order_Status', 'Payment_Method', 'Shipping_Mode', 'Year_Month']
#
# ['Seller_ID', 'Seller_Name', 'Seller_Type', 'Seller_Region']
#
# ['Order_ID', 'Product_ID', 'Seller_ID', 'Quantity', 'Discount', 'Sales', 'Cost', 'Profit', 'Order_Status']

# %%
customers_clean.to_csv("customers_clean.csv", index=False)
products_clean.to_csv("products_clean.csv", index=False)
orders_clean.to_csv("orders_clean.csv", index=False)
sellers_clean.to_csv("sellers_clean.csv", index=False)
order_items_clean.to_csv("order_items_clean.csv", index=False)

print("All cleaned datasets exported successfully.")
# Out:
# All cleaned datasets exported successfully.

# %%
import os

[f for f in os.listdir() if "_clean.csv" in f]
# Out:
# ['sellers_clean.csv',
#  'orders_clean.csv',
#  'customers_clean.csv',
#  'order_items_clean.csv',
#  'products_clean.csv']
